# %%
import pickle
with open('data/cache/MI3_train_Room_gt_roidb.pkl', 'rb') as handle:
    imgs = pickle.load(handle)

# %%
len(imgs)
# Out:
# 724

# %%
imgs
# Out:
# [{'boxes': array([[360, 182, 465, 315]], dtype=uint16),
#   'gt_classes': array([1], dtype=int32),
#   'gt_ishard': array([0], dtype=int32),
#   'gt_overlaps': <1x2 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([14204.], dtype=float32),
#   'img_id': 26,
#   'image': '/home/superorange5/Research/FedWCD/data/MI3/JPEGImages/Room_1_ch2_00127.jpg',
#   'width': 640,
#   'height': 480,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[350, 195, 452, 329]], dtype=uint16),
#   'gt_classes': array([1], dtype=int32),
#   'gt_ishard': array([0], dtype=int32),
#   'gt_overlaps': <1x2 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([13905.], dtype=float32),
#   'img_id': 27,
# ...
